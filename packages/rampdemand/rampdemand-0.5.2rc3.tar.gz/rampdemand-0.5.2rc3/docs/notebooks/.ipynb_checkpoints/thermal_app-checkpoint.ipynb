# %% [markdown]
# # Thermal loads
#
# This example input file represents a single household user whose only load
# is the "shower". The example showcases how to model thermal loads
# by means of the `thermal_P_var` attribute.

# %%
# importing functions
from ramp import User,UseCase, load_data, get_day_type
import pandas as pdwrong sizewrong sizewrong sizewrong sizewrong sizewrong sizewrong sizewrong size

# %% [markdown]
# ### Creating a user category and appliances

# %%
household = User()

# %% [markdown]
# When the power is varying during the day, the “power” parameter needs to
# be passed as a pd.DataFrame or np.array with a daily profile (365 rows
# of data). For this exercise, data can be loaded from the default
# examples in ramp:

# %%
shower_power = load_data(example="shower")

# %%
# shower power distribution
shower_power.plot()
# Out:
# <AxesSubplot:>

# %%
shower = household.add_appliance(
    name = "Shower",
    number = 1,
    power  = shower_power,
    num_windows = 2,
    func_time = 15,
    time_fraction_random_variability = 0.1,
    func_cycle = 3,
    window_1 = [390,540],
    window_2 = [1080,1200],
    random_var_w = 0.2
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 shower = household.add_appliance(
#       2     name = "Shower",
#       3     number = 1,
#       4     power  = shower_power,
#       5     num_windows = 2,
#       6     func_time = 15,
#       7     time_fraction_random_variability = 0.1,
#       8     func_cycle = 3,
#       9     window_1 = [390,540],
#      10     window_2 = [1080,1200],
#      11     random_var_w = 0.2
#      12 )
#
# File ~/Documents/repos/RAMP/ramp/core/core.py:612, in User.add_appliance(self, *args, **kwargs)
#     609     if cycle_parameters:
#     610         duty_cycle_parameters[i + 1] = cycle_parameters
# --> 612 app = Appliance(self, **kwargs)
#     614 if windows_args:
#     615     app.windows(**windows_args)
#
# File ~/Documents/repos/RAMP/ramp/core/core.py:976, in Appliance.__init__(self, user, number, power, num_windows, func_time, time_fraction_random_variability, func_cycle, fixed, fixed_cycle, occasional_use, flat, thermal_p_var, pref_index, wd_we_type, name)
#     974         power = power.values[:, 0]
#     975     else:
# --> 976         raise ValueError(f"wrong size of array. array size should be ({self.user.num_days},1).")
#     978 elif isinstance(power, str):
#     979     power = pd.read_json(power).values[:, 0]
#
# ValueError: wrong size of array. array size should be (366,1).

# %% [markdown]
# ### Generating profiles

# %%
usecase = UseCase(users=[household],date_start="2020-01-01")
usecase.initialize(num_days=365)
# Out:
# You will simulate 365 days from 2020-01-01 until 2020-12-30 00:00:00

# %%
def thermal_P_var_sensitivity(values):
    
    # buidling a pd.DataFrame for saving sensitivity results
    results = pd.DataFrame(    
        index = pd.date_range(start = "2020-01-01",periods = 1440*365,freq="T"),
        columns = [f"P_var = {value}" for value in values]
    )
    
    for value in values:
        
        # changing the thermal_P_var
        household.thermal_P_var = value
        
        profiles=usecase.generate_daily_load_profiles(flat=True)
            
        # assigning the yearly profile for a given sensitivity case
        results[f"P_var = {value}"] = profiles
        
    return results

# %%
sensitivity_results = thermal_P_var_sensitivity([0,0.25,0.5,0.75,1])

# %%
sensitivity_results
# Out:
#                      P_var = 0  P_var = 0.25  P_var = 0.5  P_var = 0.75  \
# 2020-01-01 00:00:00        0.0           0.0          0.0           0.0
# 2020-01-01 00:01:00        0.0           0.0          0.0           0.0
# 2020-01-01 00:02:00        0.0           0.0          0.0           0.0
# 2020-01-01 00:03:00        0.0           0.0          0.0           0.0
# 2020-01-01 00:04:00        0.0           0.0          0.0           0.0
# ...                        ...           ...          ...           ...
# 2020-12-30 23:55:00        0.0           0.0          0.0           0.0
# 2020-12-30 23:56:00        0.0           0.0          0.0           0.0
# 2020-12-30 23:57:00        0.0           0.0          0.0           0.0
# 2020-12-30 23:58:00        0.0           0.0          0.0           0.0
# 2020-12-30 23:59:00        0.0           0.0          0.0           0.0
#
#                      P_var = 1
# 2020-01-01 00:00:00        0.0
# 2020-01-01 00:01:00        0.0
# 2020-01-01 00:02:00        0.0
# 2020-01-01 00:03:00        0.0
# 2020-01-01 00:04:00        0.0
# ...                        ...
# 2020-12-30 23:55:00        0.0
# 2020-12-30 23:56:00        0.0
# 2020-12-30 23:57:00        0.0
# 2020-12-30 23:58:00        0.0
# 2020-12-30 23:59:00        0.0
#
# [525600 rows x 5 columns]

# %%
# showing the daily average of the load profiles
average_daily_profiles = sensitivity_results.resample("1d").mean()

# %%
average_daily_profiles.plot()
# Out:
# <AxesSubplot:>
